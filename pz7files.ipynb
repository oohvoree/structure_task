# %% [markdown]
# <a href="https://colab.research.google.com/github/oohvoree/structure_task/blob/main/pz7files.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📁** Практична робота: Робота з файлами у Python**

# %% [markdown]
# # === **Завдання 1** ===
# # Створіть файл 'my_info.txt' і запишіть 5 рядків про себе

# %% [markdown]
#  # === **Завдання 2** ===
# # Прочитайте цей файл та виведіть його вміст

# %% [markdown]
# # === **Завдання 3** ===
# Створення товарного чеку.
# Створити програму, яка дозволяє вводити інформацію про товари (назву, ціну, кількість), обчислює загальну суму та формує чек, який зберігається у текстовому файлі. Приклад чеку:

# %% [markdown]
# ![{79B2DCB2-D912-46A8-99CA-786680F67B71}.png](data:image/png;base64,...)

# %% [markdown]
# **datetime** — це стандартна бібліотека в Python для роботи з датою та часом.

# %%
from datetime import datetime
now = datetime.now().strftime("%d.%m.%Y %H:%M")
print(f"Дата: {now}")
# Out:
# Дата: 21.04.2025 19:28

# %% [markdown]
# **datetime.now()** — отримує поточну дату й час.
#
# .**strftime**(...) — форматує дату й час у зручний для читання вигляд:
#
# **%d** — день
#
# **%m** — місяць
#
# **%Y** — рік
#
# **%H:%M** — години і хвилини

# %%
from datetime import datetime

# Кошик
basket = []

print("🔍 Додавання товарів до кошика (введіть 'кінець', щоб завершити)")

while True:
    name = input("Назва товару: ")
    if name.lower() == "кінець":
        break
    price = float(input(f"Ціна товару '{name}': "))
    countTov = int(input(f"Кількість товару '{name}': "))

    # Додаємо товар у кошик
    basket.append({"name": name, "price": price, "countTov": countTov})

# Друк чеку
now = datetime.now().strftime("%d.%m.%Y %H:%M")
print("\n🧾 ТОВАРНИЙ ЧЕК")
print(f"Дата: {now}")
print("-" * 40)

sum = 0
for item in basket:
    line_sum = item["price"] * item["countTov"]
    sum += line_sum
    print(f"{item['name']:<20} x{item['countTov']:>2}  {item['price']:>6.2f} грн = {line_sum:>6.2f} грн")

print("-" * 40)
print(f"{'Загальна сума':<30} = {sum:.2f} грн")
print("Дякуємо за покупку! 🛒")

# Збереження чеку у файл 🧾 chek.txt 🛒
??????????????????????????????????????

# %% [markdown]
# ---
#
# ## 🧾 **Форматування рядків у Python  **👇
#
# Форматування дає змогу красиво вирівнювати і виводити значення в таблицях.
#
# ### ✅ f-рядок — як вставити змінну:
# ```python
# name = "Молоко"
# price = 32.5
# print(f"{name} коштує {price} грн")
# ```
#
# ---
#
# ## 📐 Вирівнювання тексту
#
# Формат: `{вираз:вирівнюванняширина}`
#
# | Приклад       | Пояснення                            |
# |---------------|--------------------------------------|
# | `:<20`        | вирівнює вліво, займає 20 символів   |
# | `:>10`        | вирівнює вправо, займає 10 символів  |
# | `:^15`        | центрує в полі з 15 символів         |
#
# **Приклад:**
# ```python
# print(f"{'Назва':<15}{'Кількість':>10}")
# print(f"{'Молоко':<15}{3:>10}")
# ```
#
# 🔸 Результат:
# ```
# Назва             Кількість
# Молоко                  3
# ```
#
# ---
#
# ## 💰 Формат чисел
#
# | Формат     | Опис                              |
# |------------|-----------------------------------|
# | `.2f`      | 2 знаки після крапки              |
# | `.0f`      | ціле число, без десяткових знаків |
#
# **Приклад:**
# ```python
# price = 32.567
# print(f"{price:.2f}")  # 32.57
# ```
